# %% [markdown]
# # Homework 3: String Operations & Debugging
#
# **Due: Monday by 11:59 PM**
#
# **Instructions:** Complete each section below. Run your code to test it. If you get stuck, refer to the reference sheet or ask questions via email.

# %% [markdown]
# ## Part 1: String Methods
#
# Use string methods to clean up and transform text.

# %%
# Run this code to see string methods in action
messy_input = "  hELLO wORLD  "
print(f"Original: '{messy_input}'")
print(f"strip():  '{messy_input.strip()}'")
print(f"upper():  '{messy_input.upper()}'")
print(f"lower():  '{messy_input.lower()}'")
print(f"title():  '{messy_input.title()}'")

# %%
# Your turn: Clean up this messy superhero name
# 1. Remove the extra spaces with strip()
# 2. Convert to title case with title()
# 3. Store the result in 'clean_hero' and print it

messy_hero = "   bRUCE wAYNE   "

# Your code here:


# Expected output: "Bruce Wayne"

# %%
# Use .replace() to fix this sentence
# Replace "terrible" with "great" and print the result

review = "Python is a terrible programming language"

# Your code here:


# Expected output: "Python is a great programming language"

# %%
# Chain three methods together:
# Take this messy text, strip spaces, convert to lowercase,
# then replace "python" with "programming"
# Store the result in 'clean_text' and print it

messy_text = "  I Love PYTHON  "

# Your code here:


# Expected output: "i love programming"

# %% [markdown]
# ## Part 2: String Indexing
#
# Access individual characters using their position number.

# %%
# Run this code to see how indexing works
word = "Spider-Man"
print(f"Word: {word}")
print(f"Length: {len(word)}")
print(f"First character: {word[0]}")
print(f"Last character: {word[-1]}")
print(f"Fifth character: {word[4]}")

# %%
# Your turn: Answer these questions about the string below
hero = "Batman"

# Print the character at index 3


# Print the character at index -2


# Print the length of hero


# Using your answers: is the character at index 3 the same as the
# character at index -2? Why or why not? (Add a comment with your answer)

# %%
# Use .index() to find positions
movie = "The Dark Knight"

# Find the position of the first space
first_space = movie.index(" ")
print(f"First space is at position: {first_space}")

# Get the first word using the space position
first_word = movie[:first_space]
print(f"First word: {first_word}")

# Your turn: get the character right after the first space
# (This should be 'D')

# Your code here:

# %% [markdown]
# ## Part 3: String Slicing
#
# Extract substrings using `[start:end]` notation.

# %%
# Run this code to see slicing in action
phrase = "Hello World"
print(f"phrase[:5] = '{phrase[:5]}'")
print(f"phrase[6:] = '{phrase[6:]}'")
print(f"phrase[0:5] = '{phrase[0:5]}'")
print(f"phrase[6:11] = '{phrase[6:11]}'")

# %%
# Your turn: Extract the username and domain from this email
# Use .index() to find the @ symbol, then slice

email = "hero@gotham.city"

# Find the position of @


# Extract username (everything before @)


# Extract domain (everything after @)


# Print both


# Expected: username = "hero", domain = "gotham.city"

# %%
# Extract the file name and extension from this filename
# Use .index() and slicing

filename = "homework.pdf"

# Find the dot position


# Extract the name part (before the dot)


# Extract the extension (after the dot)


# Print both

# Expected: name = "homework", extension = "pdf"

# %% [markdown]
# ## Part 4: F-String Formatting
#
# Create formatted output using f-strings.

# %%
# Run this code to see f-strings in action
name = "Diana Prince"
alias = "Wonder Woman"
power_level = 9.5

print(f"{name} is also known as {alias}.")
print(f"Power level: {power_level}/10")
print(f"Name in caps: {name.upper()}")
print(f"Power + 0.5 = {power_level + 0.5}")

# %%
# Your turn: Create variables for a superhero and use f-strings
# Create: hero_name (string), real_name (string), power_rating (float)
# Print a sentence using an f-string with all three variables
# Print the hero_name in uppercase using an f-string

# Your code here:

# %%
# Format numbers with f-strings
# Create a simple receipt:
# item_name = "Comic Book"
# price = 4.99
# quantity = 3
# Calculate the total (price * quantity)
# Print: "Item: Comic Book"
# Print: "Price: $4.99"
# Print: "Qty: 3"
# Print: "Total: $14.97" (use :.2f for formatting)

# Your code here:

# %% [markdown]
# ## Part 5: User Input with Strings
#
# Combine `input()`, string methods, and f-strings.

# %%
# Create a program that:
# 1. Asks the user for their full name
# 2. Cleans it up with strip() and title()
# 3. Finds the first name (everything before the first space)
# 4. Greets them with: "Welcome, [first name]."

# Your code here:

# %%
# Create a program that:
# 1. Asks the user for their email address
# 2. Cleans it with strip() and lower()
# 3. Extracts the username (before @) and domain (after @)
# 4. Prints: "Username: [username]"
# 5. Prints: "Domain: [domain]"

# Your code here:

# %% [markdown]
# ## Part 6: Debugging Practice
#
# These code cells have errors. Read the error messages carefully, find the problems, and fix them.

# %%
# Fix this code - there's an IndexError
word = "Hello"
last_letter = word[5]
print(f"Last letter: {last_letter}")

# %%
# Fix this code - there's an AttributeError
city = "gotham"
proper_city = city.Title()
print(f"City: {proper_city}")

# %%
# Fix this code - there's a NameError
hero_name = "Batman"
hero_city = "Gotham"
print(f"{hero_name} protects {hero_cty}")

# %%
# Fix this code - there are multiple issues
message = "hello world
clean_msg = message.strip().title()
first_word = clean_msg[:clean_msg.index(" ")]
print(f"First word: {frist_word}")

# %% [markdown]
# **Debugging Reflection:** In the markdown cell below, explain what types of errors you found and how you fixed them.
#
# **Your answer:**
# *(Double-click this cell to edit it)*

# %% [markdown]
# ## Reflection Questions
#
# Answer these questions in the markdown cells below:

# %% [markdown]
# **1. What is the difference between `string[3]` and `string[3:]`?**
#
# *(Double-click to edit)*
#
# Your answer:

# %% [markdown]
# **2. Why do string methods return a new string instead of changing the original?**
#
# *(Double-click to edit)*
#
# Your answer:

# %% [markdown]
# **3. What was the most challenging part of this assignment?**
#
# *(Double-click to edit)*
#
# Your answer:

# %% [markdown]
# ## Submission Instructions
#
# 1. Make sure all your code runs and the output is displayed
# 2. Complete all the reflection questions
# 3. File > Download Notebook (.ipynb)
# 4. Submit the downloaded .ipynb file to Moodle before Monday 11:59 PM
#
# Challenge problems below.

# %% [markdown]
# ## Part 7: Challenge Problems (Optional)
#
# These are extra challenges if you want more practice.

# %%
# Challenge 1: Name formatter
# Ask the user for their full name (first and last)
# Clean it up and extract first name, last name, and initials
# Print everything in a formatted summary:
# "Full name: Alice Johnson"
# "First: Alice"
# "Last: Johnson"
# "Initials: A.J."
# "Username suggestion: ajohnson"
# (username = first initial + lowercase last name)

# Your code here:

# %%
# Challenge 2: Email validator
# Ask the user for an email address
# Clean it (strip, lowercase)
# Check if it contains "@" (use: "@" in email)
# If it does, extract and display the username and domain
# If it does not, print "Invalid email: missing @ symbol"
# Also check if the domain contains "." and report

# Your code here:

# %%
# Challenge 3: Secret message decoder
# Given this encoded message, decode it step by step:
# 1. Strip whitespace
# 2. Replace all "X" with " " (space)
# 3. Replace all "@" with "a"
# 4. Convert to title case
# 5. Print the decoded message

encoded = "   pythonXisX@nX@m@zingXl@ngu@ge   "

# Your code here:
