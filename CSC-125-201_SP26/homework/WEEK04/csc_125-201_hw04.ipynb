# %% [markdown]
# # Homework 4: Math Operations & Operators
#
# **Due: Monday by 11:59 PM**
#
# **Instructions:** Complete each section below. Run your code to test it. If you get stuck, refer to the reference sheet or ask questions via email.

# %% [markdown]
# ## Part 1: Arithmetic Operators
#
# Python has seven arithmetic operators. Review how each one works, then complete the exercises.

# %%
# DEMO - Run this cell to see all 7 arithmetic operators
a = 15
b = 4

print(f"Working with a = {a} and b = {b}")
print()
print(f"Addition:       {a} + {b} = {a + b}")
print(f"Subtraction:    {a} - {b} = {a - b}")
print(f"Multiplication: {a} * {b} = {a * b}")
print(f"Division:       {a} / {b} = {a / b}")
print(f"Floor Division: {a} // {b} = {a // b}")
print(f"Modulo:         {a} % {b} = {a % b}")
print(f"Exponentiation: {a} ** {b} = {a ** b}")

# %%
# Exercise: Shopping calculation
# You are buying multiple items at the same price.
# 1. Create a variable called total_cost that stores the total price of all items
# 2. Create a variable called change_from_100 that stores how much change
#    you would get back if you paid with $100
# 3. Print both results using f-strings with :.2f formatting

items = 7
price_per_item = 12.50

# Your code here:


# Expected output:
# Total cost: $87.50
# Change from $100: $12.50

# %% [markdown]
# ## Part 2: Floor Division & Modulo
#
# Floor division (`//`) and modulo (`%`) are especially useful for breaking quantities into groups.

# %%
# DEMO - Run this cell to see time conversion with // and %
total_seconds = 3900

hours = total_seconds // 3600
remaining = total_seconds % 3600
minutes = remaining // 60
seconds = remaining % 60

print(f"{total_seconds} seconds = {hours} hour(s), {minutes} minute(s), {seconds} second(s)")

# %%
# Exercise: Day conversion
# Convert a number of days into weeks and remaining days.
# Hint: look at how the demo splits seconds into hours and minutes.
# 1. Create a variable called weeks that stores the number of full weeks
# 2. Create a variable called remaining_days that stores the leftover days
# 3. Print the result

total_days = 100

# Your code here:


# Expected output:
# 100 days = 14 weeks and 2 days

# %% [markdown]
# ## Part 3: Operator Precedence
#
# Python follows the mathematical order of operations (PEMDAS). Parentheses let you control the order.

# %%
# DEMO - Run this cell to see how precedence changes the result
result_no_parens = 2 + 3 * 4
result_with_parens = (2 + 3) * 4

print(f"2 + 3 * 4   = {result_no_parens}")
print(f"(2 + 3) * 4 = {result_with_parens}")
print()
print("Without parentheses: multiplication happens first (3 * 4 = 12, then 2 + 12 = 14)")
print("With parentheses: addition happens first (2 + 3 = 5, then 5 * 4 = 20)")

# %%
# Exercise: Calculate the average of four test scores
# Make sure to use parentheses so the addition happens before the division.

t1 = 88
t2 = 92
t3 = 75
t4 = 95

# Calculate the average - be careful with parentheses

# Your code here:


# Print the average with :.1f formatting


# Expected output:
# Average test score: 87.5

# %% [markdown]
# ## Part 4: Comparison Operators & Booleans
#
# Comparison operators return `True` or `False`. You can store these results in variables.

# %%
# DEMO - Run this cell to see comparisons with a movie example
movie_title = "The Dark Knight"
release_year = 2008
rating = 9.0
runtime_minutes = 152

is_recent = release_year >= 2020
is_highly_rated = rating > 8.0
is_long = runtime_minutes > 120
is_exact_two_hours = runtime_minutes == 120

print(f"Movie: {movie_title} ({release_year})")
print(f"Released in 2020 or later: {is_recent}")
print(f"Rating above 8.0: {is_highly_rated}")
print(f"Longer than 2 hours: {is_long}")
print(f"Exactly 2 hours: {is_exact_two_hours}")

# %%
# Exercise: Budget check with tax
# You want to know if you can afford an item after tax is added.
# Hint: the demo stores comparisons like is_highly_rated = rating > 8.0
# 1. Create a variable called price_with_tax that stores the full price
#    after tax. The tax amount is the price times the tax rate — add that
#    to the original price.
# 2. Create a boolean variable called within_budget that stores whether
#    the price with tax is within your budget
# 3. Print the price with tax (:.2f) and whether it is within budget

price = 24.99
budget = 30.00
tax_rate = 0.08

# Your code here:


# Expected output:
# Price with 8% tax: $26.99
# Within $30.00 budget: True

# %% [markdown]
# ## Part 5: Assignment Operators
#
# Assignment operators (`+=`, `-=`, `*=`, `/=`) let you update a variable based on its current value.

# %%
# DEMO - Run this cell to see assignment operators in action
score = 0
print(f"Starting score: {score}")

score += 100    # same as score = score + 100
print(f"After += 100:   {score}")

score -= 25     # same as score = score - 25
print(f"After -= 25:    {score}")

score *= 2      # same as score = score * 2
print(f"After *= 2:     {score}")

# %%
# Exercise: Game stat tracker
# Track a player's health and gold through a series of events.
# Use assignment operators (+=, -=, *=) for each update.
# Write your code on the blank line above each print statement.

health = 100
gold = 50
print(f"Start     -> Health: {health}, Gold: {gold}")

# Event 1: Lose 30 health (use -=)


print(f"Take hit  -> Health: {health}, Gold: {gold}")

# Event 2: Find 75 gold (use +=)


print(f"Find gold -> Health: {health}, Gold: {gold}")

# Event 3: Double your gold (use *=)


print(f"Jackpot   -> Health: {health}, Gold: {gold}")

# Expected output:
# Start     -> Health: 100, Gold: 50
# Take hit  -> Health: 70, Gold: 50
# Find gold -> Health: 70, Gold: 125
# Jackpot   -> Health: 70, Gold: 250

# %% [markdown]
# ## Part 6: Integration
#
# These exercises combine multiple concepts from this week.

# %%
# Exercise: Receipt calculator
# Calculate and print a formatted receipt.
# 1. Create a variable called subtotal that stores the sum of all three items
# 2. Create a variable called tax that stores the tax amount at 8%
# 3. Create a variable called total that stores the final price after tax
# 4. Print a formatted receipt using f-strings and :.2f
#    (Don't worry about lining up the dollar signs perfectly)

item1 = 12.99
item2 = 8.50
item3 = 15.75

# Your code here:


# Expected output:
# --- Receipt ---
# Item 1: $12.99
# Item 2: $8.50
# Item 3: $15.75
# Subtotal: $37.24
# Tax (8%): $2.98
# Total: $40.22

# %% [markdown]
# ## Part 7: Debugging Practice
#
# Each cell below contains code with a bug. Read the error message (or incorrect output), find the problem, and fix it.

# %%
# Bug 1: TypeError - something is the wrong type
# This should add the base price and the delivery fee.
# Find the bug and fix it.

base_price = "29.99"
delivery_fee = 5.00
total = base_price + delivery_fee
print(f"Total: ${total}")

# %%
# Bug 2: Wrong result - the total is incorrect
# This should calculate the average temperature for three days.
# The correct average should be approximately 72.7.
# Run it, notice the wrong answer, and fix the precedence issue.

day1, day2, day3 = 72, 65, 81
avg_temp = day1 + day2 + day3 / 3
print(f"Average temperature: {avg_temp}")

# %% [markdown]
# **Debugging Reflection:** Answer the following in this cell.
#
# 1. For Bug 1, what type of error did you get? What caused it and how did you fix it?
# 2. For Bug 2, what was the wrong output? What caused the wrong result and how did you fix it?
#
# *(Double-click this cell to edit it)*
#
# Your answer:

# %% [markdown]
# ## Reflection Questions
#
# Answer these questions in the markdown cells below:

# %% [markdown]
# **1. What is the difference between `/` and `//` in Python? When would you use each?**
#
# *(Double-click to edit)*
#
# Your answer:

# %% [markdown]
# **2. Why does `2 + 3 * 4` equal 14 and not 20?**
#
# *(Double-click to edit)*
#
# Your answer:

# %% [markdown]
# ## Submission Instructions
#
# 1. Make sure all your code runs and the output is displayed
# 2. Complete all the reflection questions
# 3. File > Download Notebook (.ipynb)
# 4. Submit the downloaded .ipynb file to Moodle before Monday 11:59 PM
#
# Challenge problems below.

# %% [markdown]
# ## Part 8: Challenge Problems (Optional)
#
# These are extra challenges if you want more practice.

# %%
# Challenge 1: Temperature converter
# Given the temperature in Fahrenheit below:
# 1. Convert to Celsius using the formula: (F - 32) * 5 / 9
# 2. Convert to Kelvin: Celsius + 273.15
# 3. Store whether it is below freezing (Celsius < 0) as a boolean
# 4. Print all results formatted with :.2f

fahrenheit = 72.0

# Your code here:

# %%
# Challenge 2: Loan payment estimator
# Given the loan details below, calculate the monthly payment.
# Formula: payment = principal * (r * (1 + r) ** n) / ((1 + r) ** n - 1)
#   where r = monthly rate, n = number of payments
# 1. Create a variable called monthly_rate (the annual rate split across 12 months)
# 2. Create a variable called num_payments (total number of monthly payments)
# 3. Create a variable called monthly_payment using the formula above
# 4. Create a variable called total_paid for the total amount paid over the loan
# 5. Print monthly payment and total paid with :.2f formatting

principal = 10000
annual_rate = 0.065
years = 5

# Your code here:


# Expected output:
# Monthly payment: $195.66
# Total paid: $11739.84

# %%
# Challenge 3: Number properties analyzer
# Given the number below, figure out and print the following:
#   - Is it even?
#   - Is it positive?
#   - Is it negative?
#   - Is it zero?
# Store each answer in a descriptively named boolean variable.
# No if/else needed - just print the boolean values directly.

number = 42

# Your code here:
