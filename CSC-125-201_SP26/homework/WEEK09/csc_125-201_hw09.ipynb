# %% [markdown]
# # Homework 9: While Loops & Midterm Prep
#
# **Due: Monday by 11:59 PM**
#
# **This homework is shorter than usual.** Part 1 is a quick while loop practice from this week's material. Parts 2-4 are midterm prep, formatted like the exam to help you study. The midterm covers **Weeks 1-8 only** (no while loops), so Parts 2-4 focus on that material.
#
# **Instructions:** Complete each section below. Run your code to test it. If you get stuck, refer to the reference sheet or ask questions via email.

# %% [markdown]
# ## Part 1: While Loop Practice
#
# These exercises practice the new material from this week.

# %%
# Exercise 1: Savings goal.
# You have $200 in savings and add $75 each month.
# Use a while loop to find how many months until you
# reach at least $800. Print the month number and
# balance each iteration, then print the final count.

balance = 200
goal = 800

# Your code here:


# Expected output:
# Month 1: $275
# Month 2: $350
# Month 3: $425
# Month 4: $500
# Month 5: $575
# Month 6: $650
# Month 7: $725
# Month 8: $800
# Reached goal in 8 months

# %%
# Exercise 2: Data cleaner.
# The list below contains raw survey ratings. Some entries
# are valid numbers, some are not. Use a while loop with an
# index variable to step through the list one entry at a time.
# Use try/except to catch invalid entries.
# Build a list of valid integers and count how many were skipped.

raw_data = ["5", "3", "bad", "4", "", "2", "N/A", "5"]

# Your code here:


# Expected output:
# Valid ratings: [5, 3, 4, 2, 5]
# Skipped: 3
# Average rating: 3.8

# %% [markdown]
# ---
#
# ## Part 2: Output Prediction (Midterm Prep)
#
# The midterm has a section where you read code and write exactly what it prints. For each cell below, **write your prediction in the comment first**, then run the cell to check. These cover Weeks 1-8 material only.

# %%
# Predict the output, then run to check.
#
# Your prediction:
#

total = 0
prices = [8, 15, 3, 12]
for price in prices:
    total = total + price
print(total)

# %%
# Predict the output, then run to check.
#
# Your prediction:
#

items = ["pen", "notebook", "eraser", "ruler"]
items.append("tape")
items.remove("eraser")
print(items[1:])
print(len(items))

# %%
# Predict the output, then run to check.
#
# Your prediction:
#

word = "Programming"
result = ""
for char in word:
    if char.lower() in "aeiou":
        result = result + char
print(result)

# %%
# Predict the output, then run to check.
#
# Your prediction:
#

temp = 72
if temp >= 80:
    label = "Hot"
elif temp >= 60:
    label = "Warm"
else:
    label = "Cold"

is_comfortable = temp > 68 and temp < 76
print(f"{label}, comfortable: {is_comfortable}")

# %%
# Predict the output, then run to check.
#
# Your prediction:
#

count = 0
for i in range(1, 8):
    if i % 2 == 0:
        count = count + 1
print(count)

# %%
# Predict the output, then run to check.
#
# Your prediction:
#

name = "Python Course"
print(name[0] + name[-1])
print(name[7:13])
print(len(name))

# %% [markdown]
# ---
#
# ## Part 3: Fix the Errors (Midterm Prep)
#
# The midterm has a section where each code block has exactly one error. Find the bug, fix it, and run the cell to verify.

# %%
# Bug 1: Logic error - this should print the total of all prices
# ($54.48), but it prints the wrong number.

prices = [12.99, 8.50, 15.75, 17.24]
total = 0

for price in prices:
    total = price

print(f"Total: ${total:.2f}")

# %%
# Bug 2: SyntaxError - the colon is missing.

score = 85

if score >= 90
    grade = "A"
elif score >= 80:
    grade = "B"
else:
    grade = "C"

print(grade)

# %%
# Bug 3: Logic error - this should print the average of three
# scores (80.0), but it prints the wrong number.
# Hint: think about order of operations.

s1 = 75
s2 = 90
s3 = 75

average = s1 + s2 + s3 / 3
print(f"Average: {average}")

# %%
# Bug 4: IndexError - should print all three colors but crashes.

colors = ["red", "green", "blue"]

for i in range(1, 4):
    print(colors[i])

# %% [markdown]
# ---
#
# ## Part 4: Code Writing (Midterm Prep)
#
# The midterm has sections where you write short code (3-5 lines) and complete programs. These practice the same skills.

# %%
# Exercise 3: Write a for loop that goes through the list
# of temperatures and counts how many are below freezing
# (below 32). Print the count.

temps = [28, 35, 31, 42, 19, 33, 27]

# Your code here:


# Expected output:
# Below freezing: 4

# %%
# Exercise 4: Write code using range(len()) to print each
# employee paired with their department from the two lists.

employees = ["Garcia", "Chen", "Patel"]
departments = ["Sales", "Engineering", "Marketing"]

# Your code here:


# Expected output:
# Garcia - Sales
# Chen - Engineering
# Patel - Marketing

# %%
# Exercise 5: Write a program that finds the most expensive item
# and formats a receipt summary. Use a for loop with range(len())
# to find which item has the highest price, then print the receipt.

items = ["Coffee", "Bagel", "Salad", "Juice", "Muffin"]
prices = [4.50, 3.25, 8.99, 5.75, 3.50]

# Your code here:


# Expected output:
# --- Receipt ---
# Coffee: $4.50
# Bagel: $3.25
# Salad: $8.99
# Juice: $5.75
# Muffin: $3.50
# Most expensive: Salad ($8.99)

# %% [markdown]
# ---
#
# ## Reflection Questions

# %% [markdown]
# **1. What is the difference between a for loop and a while loop? When would you use each one?**
#
# *(Double-click to edit)*
#
# Your answer:

# %% [markdown]
# **3. What was the most challenging part of this homework?**
#
# *(Double-click to edit)*
#
# Your answer:

# %% [markdown]
# **2. What concept from Weeks 1-8 do you feel least confident about going into the midterm?**
#
# *(Double-click to edit)*
#
# Your answer:

# %% [markdown]
# ---
#
# ## Submission Instructions
#
# 1. Make sure all your code runs and the output is displayed
# 2. Complete the reflection questions
# 3. File > Download Notebook (.ipynb)
# 4. Submit the downloaded .ipynb file to Moodle before Monday 11:59 PM
#
# **Reminder:** The midterm is next week (Week 10). Review the practice exam on Moodle.
